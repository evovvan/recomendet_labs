# %% [markdown]
# # Домашнее задание по обработке текстов
#
# ## Предсказание цены акции по экономическим новостям
#
# Входные данные:
# * Новости о компании "Газпром", начиная с 2010 года
# * Стоимость акций компании "Газпром" на ММВБ, начиная с 2010 года
#     * цена открытия (Open)
#     * цена закрытия (ClosingPrice)
#     * максимальная цена за день (DailyHigh)
#     * минимальная цена за день (DailyLow)
#     * объем бумаг (VolumePcs)

# %%
import pandas as pd
df = pd.read_csv('texts.csv',encoding='utf-8')
df.head(30)
# Out:
#           date                                               text
# 0   09.11.2017  Компания рассчитывает на решение по газовому с...
# 1   08.11.2017   Как и предполагал “Ъ”, «Газпром», воспользова...
# 2   01.11.2017   Новая редакция американских санкций ставит по...
# 3   30.10.2017   Как стало известно “Ъ”, известный на рынке ри...
# 4   23.10.2017   НОВАТЭК, который через пять лет собирается за...
# 5   20.10.2017   Российским прокатчикам второй раз за год приш...
# 6   13.10.2017   «Газпром» может подписать контракт со Словени...
# 7   05.10.2017   «Газпром нефть», пробурившая первую скважину ...
# 8   04.10.2017   Спутниковый оператор «НТВ-плюс» в последнее в...
# 9   29.09.2017   Как стало известно “Ъ”, конкуренты начинают р...
# 10  22.09.2017   «Газпром» и НОВАТЭК могут принять участие в к...
# 11  18.09.2017   «Газпром» впервые с 2010 года вернет себе рол...
# 12  13.09.2017   Сегодня Банк России опубликовал на своем сайт...
# 13  12.09.2017   Интерес традиционной тепловой генерации к воз...
# 14  08.09.2017   «Газпром» и «Нафтогаз» ожидаемо не смогли дог...
# 15  07.09.2017   Помощник президента России Андрей Белоусов за...
# 16  04.09.2017   «Роснефть» первой из крупных российских госко...
# 17  31.08.2017   Выручка «Газпром-медиа» в первом полугодии ро...
# 18  21.08.2017   После ухода с поста канцлера ФРГ Ангела Мерке...
# 19  17.08.2017   «Газпром» уверенно идет к новому абсолютному ...
# 20  16.08.2017   Градообразующее предприятие Инты АО «Интаугол...
# 21  14.08.2017   Как стало известно “Ъ”, у «Газпром нефти» воз...
# 22  10.08.2017   «Газпром» отрапортовал о 90-процентной загруз...
# 23  07.08.2017   С оглядкой на успех турецкой телесаги «Велико...
# 24  03.08.2017   Россия останется «надежным гарантом энергобез...
# 25  28.07.2017   Спустя полгода «Газпром» снова получил возмож...
# 26  27.07.2017   Статьи Sports.ru, опубликованные на одном из ...
# 27  26.07.2017   «Татнефть» хочет потеснить крупные нефтекомпа...
# 28  24.07.2017   «» считает положительным разрешение ситуации ...
# 29  18.07.2017   Российский фонд прямых инвестиций (РФПИ), вла...

# %%
pr_all = pd.read_csv('gazprom_prices.csv', sep=';', encoding='utf-8')
pr_all.head(30)
# Out:
#           Date       Open ClosingPrice  DailyHigh   DailyLow  VolumePcs
# 0   08.12.2017  133,43000    132,60000  133,90000  132,00000   16037970
# 1   07.12.2017  133,70000    133,02000  133,87000  132,81000   18198430
# 2   06.12.2017  133,33000    134,00000  134,29000  132,91000   14641730
# 3   05.12.2017  133,48000    133,65000  133,99000  132,78000   12684800
# 4   04.12.2017  133,01000    133,77000  134,00000  131,93000   17818980
# 5   01.12.2017  132,49000    133,02000  133,32000  131,72000   24755830
# 6   30.11.2017  133,00000    132,15000  134,31000  132,00000   40024830
# 7   29.11.2017  134,85000    133,55000  134,86000  132,97000   27263040
# 8   28.11.2017  133,23000    135,18000  135,18000  132,55000   26663710
# 9   27.11.2017  133,69000    133,50000  135,19000  132,80000   27713150
# 10  24.11.2017  131,56000    133,57000  134,19000  131,31000   29043690
# 11  23.11.2017  132,69000    131,60000  133,10000  131,30000   29106430
# 12  22.11.2017  133,00000    132,57000  133,65000  132,20000   25211140
# 13  21.11.2017  130,45000    132,49000  133,05000  130,35000   35532230
# 14  20.11.2017  129,97000    129,96000  130,49000  128,63000   15667470
# 15  17.11.2017  129,65000    129,65000  130,87000  129,06000   18126930
# 16  16.11.2017  131,65000    129,20000  132,70000  127,74000   42122000
# 17  15.11.2017  132,01000    131,21000  132,79000  131,21000   23349160
# 18  14.11.2017  133,02000    132,93000  134,28000  132,35000   42200310
# 19  13.11.2017  132,64000    133,32000  134,18000  131,71000   29457680
# 20  10.11.2017  131,03000    132,50000  133,84000  130,51000   47147150
# 21  09.11.2017  132,31000    131,50000  132,82000  131,14000   33869650
# 22  08.11.2017  132,00000    132,30000  133,94000  131,58000   39381960
# 23  07.11.2017  127,06000    132,28000  132,55000  127,05000   82333460
# 24  03.11.2017  125,70000    125,90000  126,84000  125,70000   22633490
# 25  02.11.2017  125,88000    125,67000  126,00000  124,87000   15593170
# 26  01.11.2017  126,40000    126,50000  126,89000  125,97000   18232550
# 27  31.10.2017  126,14000    125,90000  126,60000  125,57000   11857510
# 28  30.10.2017  125,96000    125,98000  126,93000  125,53000   19263340
# 29  27.10.2017  124,55000    125,94000  125,94000  123,64000   28588870

# %%
pr_all.rename(index=str, columns={"Date": "date"}, inplace= True)

# %%
df.date = pd.to_datetime(df.date, dayfirst=True, errors='coerce')

# %%
df.head()
# Out:
#         date                                               text
# 0 2017-11-09  Компания рассчитывает на решение по газовому с...
# 1 2017-11-08   Как и предполагал “Ъ”, «Газпром», воспользова...
# 2 2017-11-01   Новая редакция американских санкций ставит по...
# 3 2017-10-30   Как стало известно “Ъ”, известный на рынке ри...
# 4 2017-10-23   НОВАТЭК, который через пять лет собирается за...

# %%
pr_all.date = pd.to_datetime(pr_all.date, dayfirst=True, errors='coerce')

# %%
pr_all.head()
# Out:
#         date       Open ClosingPrice  DailyHigh   DailyLow  VolumePcs
# 0 2017-12-08  133,43000    132,60000  133,90000  132,00000   16037970
# 1 2017-12-07  133,70000    133,02000  133,87000  132,81000   18198430
# 2 2017-12-06  133,33000    134,00000  134,29000  132,91000   14641730
# 3 2017-12-05  133,48000    133,65000  133,99000  132,78000   12684800
# 4 2017-12-04  133,01000    133,77000  134,00000  131,93000   17818980

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#                        date                                               text
# count                  1203                                               1203
# unique                 1203                                               1202
# top     2017-10-30 00:00:00   "Газпром" больше не будет компенсировать сотр...
# freq                      1                                                  2
# first   2010-01-04 00:00:00                                                NaN
# last    2017-11-09 00:00:00                                                NaN

# %%
pr_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1988 entries, 0 to 1987
# Data columns (total 6 columns):
# date            1988 non-null datetime64[ns]
# Open            1964 non-null object
# ClosingPrice    1988 non-null object
# DailyHigh       1986 non-null object
# DailyLow        1986 non-null object
# VolumePcs       1988 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 108.7+ KB

# %%
pr_all.describe()
# Out:
#           VolumePcs
# count  1.988000e+03
# mean   4.432934e+07
# std    2.424019e+07
# min    7.017140e+06
# 25%    2.731040e+07
# 50%    3.796464e+07
# 75%    5.552437e+07
# max    2.024663e+08

# %%
pr_all.dropna(inplace=True)

# %%
pr_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1964 entries, 0 to 1987
# Data columns (total 6 columns):
# date            1964 non-null datetime64[ns]
# Open            1964 non-null object
# ClosingPrice    1964 non-null object
# DailyHigh       1964 non-null object
# DailyLow        1964 non-null object
# VolumePcs       1964 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 107.4+ KB

# %%
all_data = df.merge(pr_all, on='date', how='left', sort=False)
all_data = all_data.dropna()
print(all_data.info())
all_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1145 entries, 0 to 1201
# Data columns (total 7 columns):
# date            1145 non-null datetime64[ns]
# text            1145 non-null object
# Open            1145 non-null object
# ClosingPrice    1145 non-null object
# DailyHigh       1145 non-null object
# DailyLow        1145 non-null object
# VolumePcs       1145 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 71.6+ KB
# None
#         date                                               text       Open  \
# 0 2017-11-09  Компания рассчитывает на решение по газовому с...  132,31000
# 1 2017-11-08   Как и предполагал “Ъ”, «Газпром», воспользова...  132,00000
# 2 2017-11-01   Новая редакция американских санкций ставит по...  126,40000
# 3 2017-10-30   Как стало известно “Ъ”, известный на рынке ри...  125,96000
# 4 2017-10-23   НОВАТЭК, который через пять лет собирается за...  127,05000
#
#   ClosingPrice  DailyHigh   DailyLow   VolumePcs
# 0    131,50000  132,82000  131,14000  33869650.0
# 1    132,30000  133,94000  131,58000  39381960.0
# 2    126,50000  126,89000  125,97000  18232550.0
# 3    125,98000  126,93000  125,53000  19263340.0
# 4    126,80000  127,47000  126,37000  17308800.0

# %% [markdown]
# ### Часть 1. Вводная
#
# Проведите предобработку текстов: если считаете нужным, выполните токенизацию, приведение к нижнему регистру, лемматизацию и/или стемминг. Ответьте на следующие вопросы:
# * Есть ли корреляция между средней длинной текста за день и ценой закрытия?
# * Есть ли корреляция между количеством упоминаний Алексея Миллера  и ценой закрытия? Учтите разные варианты написания имени.
# * Упоминаний какого газопровода в статьях больше:
#     * "северный поток"
#     * "турецкий поток"?
# * О каких санкциях пишут в статьях?

# %%
# Токинезация  и приведение к нижнему регистру
import re
regex = re.compile("[А-Яа-я----]+")

def words_only(text, regex=regex):
    return " ".join(regex.findall(text))


all_data.text = all_data.text.str.lower()
all_data.text = all_data.text.apply(words_only)

# %%
all_data.text.iloc[6]
# Out:
# 'газпром может подписать контракт со словенией на поставки газа на ближайшие пять лет в конце текущего начале следующего годов его условия стороны обсуждают уже несколько месяцев но не торопятся с заключением последний раз условия соглашения пересматривались в году поставки в страну составляют около млрд кубометров'

# %%
# удаление стоп слов
from nltk.corpus import stopwords
mystopwords = stopwords.words('russian') + ['это', 'наш' , 'тыс', 'млн', 'млрд', 'также',  'т', 'д', '-', '-']

print(mystopwords)
def  remove_stopwords(text, mystopwords = mystopwords):
    try:
        return " ".join([token for token in text.split() if not token in mystopwords])
    except:
        return ""
all_data.text = all_data.text.apply(remove_stopwords)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между', 'это', 'наш', 'тыс', 'млн', 'млрд', 'также', 'т', 'д', '-', '-']

# %%
# Лематизация


from pymystem3 import Mystem

m = Mystem()
def lemmatize(text, mystem=m):
    try:
        return "".join(m.lemmatize(text)).strip()  
    except:
        return " "

df.text = df.text.apply(lemmatize)

# %%
# Удаление стоп-лемм
mystoplemmas = ['который','прошлый','сей', 'свой', 'наш', 'мочь']
def  remove_stoplemmas(text, mystoplemmas = mystoplemmas):
    try:
        return " ".join([token for token in text.split() if not token in mystoplemmas])
    except:
        return ""

df.text = df.text.apply(remove_stoplemmas)

# %% [markdown]
# ### Корреляция между средней длинной текста за день и ценой закрытия

# %%
len_data = df.text.apply(len)
len_data.describe()
# Out:
# count    1203.000000
# mean      759.280133
# std       542.938752
# min         1.000000
# 25%       401.000000
# 50%       575.000000
# 75%       988.000000
# max      4120.000000
# Name: text, dtype: float64

# %%
from scipy.stats import spearmanr
import seaborn as sns

# %%
len_corr_price = pd.DataFrame({'length' : all_data.text.apply(len), 'price': all_data.ClosingPrice}) 
len_corr_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1145 entries, 0 to 1201
# Data columns (total 2 columns):
# length    1145 non-null int64
# price     1145 non-null object
# dtypes: int64(1), object(1)
# memory usage: 66.8+ KB

# %%
len_corr_price['price'] = len_corr_price['price'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-2bff61a356e1> in <module>()
# ----> 1 len_corr_price['price'] = len_corr_price['price'].astype('int')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3222
#    3223     def astype(self, dtype, **kwargs):
# -> 3224         return self.apply('astype', dtype=dtype, **kwargs)
#    3225
#    3226     def convert(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     469     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     470         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 471                             **kwargs)
#     472
#     473     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, raise_on_error, **kwargs)
#     519
#     520                 # _astype_nansafe works fine with 1-d only
# --> 521                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     522                 values = values.reshape(self.shape)
#     523
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     618
#     619         if not np.isfinite(arr).all():
# --> 620             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     621                              'integer')
#     622
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
# %matplotlib inline
corr = spearmanr(len_corr_price.length, len_corr_price.price).correlation
corr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-3acf22b31a75> in <module>()
#       1 get_ipython().magic('matplotlib inline')
# ----> 2 corr = spearmanr(len_corr_price.length, len_corr_price.price).correlation
#       3 corr
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in spearmanr(a, b, axis, nan_policy)
#    3317
#    3318             if nan_policy == 'propagate':
# -> 3319                 rho, pval = mstats_basic.spearmanr(a, b, axis)
#    3320                 return SpearmanrResult(rho * np.nan, pval * np.nan)
#    3321
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\mstats_basic.py in spearmanr(x, y, use_ties)
#     467     df = n-2
#     468     if df < 0:
# --> 469         raise ValueError("The input must have at least 3 entries!")
#     470
#     471     # Gets the ranks and rank differences
#
# ValueError: The input must have at least 3 entries!

# %%
sns.jointplot(x='length', y='price', 
              data=len_corr_price, kind='scatter');
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-158-bd2212899382> in <module>()
#       1 sns.jointplot(x='length', y='price',
# ----> 2               data=len_corr_price, kind='scatter');
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2227         marginal_kws.setdefault("kde", False)
#    2228         marginal_kws.setdefault("color", color)
# -> 2229         grid.plot_marginals(distplot, **marginal_kws)
#    2230
#    2231     elif kind.startswith("hex"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1761         kwargs["vertical"] = False
#    1762         plt.sca(self.ax_marg_x)
# -> 1763         func(self.x, **kwargs)
#    1764
#    1765         kwargs["vertical"] = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     206     if hist:
#     207         if bins is None:
# --> 208             bins = min(_freedman_diaconis_bins(a), 50)
#     209         hist_kws.setdefault("alpha", 0.4)
#     210         hist_kws.setdefault("normed", norm_hist)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      27     # From http://stats.stackexchange.com/questions/798/
#      28     a = np.asarray(a)
# ---> 29     h = 2 * iqr(a) / (len(a) ** (1 / 3))
#      30     # fall back to sqrt(a) bins if iqr is 0
#      31     if h == 0:
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ### Корреляция между количеством упоминаний Алексея Миллера и ценой закрытия.

# %%
# %matplotlib inline
corr = spearmanr(rankings).correlation
sns.heatmap(corr, annot=True, xticklabels = list(rankings), yticklabels = list(rankings))

# %% [markdown]
# ### Упоминаний какого газопровода в статьях больше:
# "северный поток "турецкий поток"?

# %% [markdown]
# ### Находим все прилагательные, стоящие перед словом "санкции"

# %% [markdown]
# ## Часть 2. Классификационная
# Вам предстоит решить следующую задачу: по текстам новостей за день определить, вырастет или понизится цена закрытия.
# Для этого:
# * бинаризуйте признак "цена закрытия":  новый признак ClosingPrice_bin равен 1, если по сравнению со вчера цена не упала, и 0 – в обратном случаея;
# * составьте бучающее и тестовое множество: данные до начала 2016 года используются для обучения, данные с 2016 года и позже – для тестирования.
#
# Таким образом, в каждлый момент времени мы знаем:
# * ClosingPrice_bin – бинарый целевой признак
# * слова из статей, опубликованных в этот день – объясняющие признаки
#
# В этой части задания вам нужно сделать baseline алгоритм и попытаться его улучшить в следующей части.
#
# Используйте любой известный вам алгоритм классификации текстов для того, Используйте $tf-idf$ преобразование, сингулярное разложение, нормировку признакого пространства и любые другие техники обработки данных, которые вы считаете нужным. Используйте accuracy и F-measure для оценки качества классификации. Покажите, как  $tf-idf$ преобразование или сингулярное разложение или любая другая использованная вами техника влияет на качество классификации.
# Если у выбранного вами алгоритма есть гиперпараметры (например, $\alpha$ в преобразовании Лапласа для метода наивного Байеса), покажите, как изменение гиперпараметра влияет на качество классификации.

# %% [markdown]
# ## Часть 3. Творческая
# Придумайте и попытайтесь сделать еще что-нибудь, чтобы улучшить качество классификации.
# Направления развития:
# * Морфологический признаки:
#     * использовать в качестве признаков только существительные или только именованные сущности;
# * Модели скрытых тем:
#     * использовать в качестве признаков скрытые темы;
#     * использовать в качестве признаков динамические скрытые темы
#     пример тут: (https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb)
# * Синтаксические признаки:
#     * использовать SOV-тройки в качестве признаков
#     * кластеризовать SOV-тройки по эмбеддингам глаголов (обученные word2vec модели можно скачать отсюда: (http://rusvectores.org/ru/models/) и использовать только центроиды кластеров в качестве признаков
# * что-нибудь еще
